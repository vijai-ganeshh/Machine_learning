# %%
import pandas as pd
df = pd.read_csv('data.csv')
#fetch the first 5 rows
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.tail()
# Out:
#           Date Category  Value   Product  Sales Region
# 45  2023-02-15        B   99.0  Product2  599.0   West
# 46  2023-02-16        B    6.0  Product1  938.0  South
# 47  2023-02-17        B   69.0  Product3  143.0   West
# 48  2023-02-18        C   65.0  Product3  182.0  North
# 49  2023-02-19        C   11.0  Product3  708.0  North

# %%
df.describe()
# Out:
#            Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000

# %%
df.dtypes
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %%
df_fill = df.fillna(0)
df_fill
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    0.0   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    0.0  Product1  895.0  North
# ...

# %%
df['sales_fillNa'] = df['Sales'].fillna(df['Sales'].mean())
df

# %%
df.dtypes
# Out:
# Date             object
# Category         object
# Value           float64
# Product          object
# Sales           float64
# Region           object
# sales_fillNa    float64
# dtype: object

# %%
#rename column 
df = df.rename(columns={'Sale Date':'Sales Date'})
df.head()
# Out:
#    Sales Date Category  Value   Product  Sales Region  sales_fillNa
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0

# %%
df['Value_new']=df['Value'].fillna(df['Value'].mean()).astype(int)
df.head()
# Out:
#    Sales Date Category  Value   Product  Sales Region  sales_fillNa  Value_new
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0         28
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0         39
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0         32
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0          8
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0         26

# %%
df['new_val']  = df['Value_new'].apply(lambda x: x*2)
df.head()
# Out:
#    Sales Date Category  Value   Product  Sales Region  sales_fillNa  \
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0
#
#    Value_new  new_val
# 0         28       56
# 1         39       78
# 2         32       64
# 3          8       16
# 4         26       52

# %%
#Data aggregating and grouping 
grouped_mean = df.groupby('Product')['Value'].mean()
print(grouped_mean)
# Out:
# Product
# Product1    46.214286
# Product2    52.800000
# Product3    55.166667
# Name: Value, dtype: float64

# %%
grouped_sum = df.groupby(['Product','Region'])['Value'].sum()
print(grouped_sum)
# Out:
# Product   Region
# Product1  East      292.0
#           North       9.0
#           South     100.0
#           West      246.0
# Product2  East       56.0
#           North     127.0
#           South     181.0
#           West      428.0
# Product3  East      202.0
#           North     203.0
#           South     215.0
#           West      373.0
# Name: Value, dtype: float64

# %%
## aggregate multiple functions
grouped_agg = df.groupby('Region')['Value'].agg(['mean','sum','count'])
grouped_agg
# Out:
#              mean     sum  count
# Region
# East    42.307692   550.0     13
# North   37.666667   339.0      9
# South   62.000000   496.0      8
# West    61.588235  1047.0     17

# %%
### Merging and joining dataframes
# create sample dataframe

df1 = pd.DataFrame({'Key':['A','B','C'],'Value1':[1,2,3]})
df2 = pd.DataFrame({'Key':['A','B','D'],'Value2':[4,5,6]})

df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
#Merge Dataframes on Key Columns
pd.merge(df1,df2,on="Key",how="inner")
# Out:
#   Key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
pd.merge(df1,df2,on="Key",how="outer")
# Out:
#   Key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
pd.merge(df1,df2,on="Key",how="left")
# Out:
#   Key  Value1  Value2
# 0   A       1     4.0
# 1   B       2     5.0
# 2   C       3     NaN

# %%
pd.merge(df1,df2,on="Key",how="right")
# Out:
#   Key  Value1  Value2
# 0   A     1.0       4
# 1   B     2.0       5
# 2   D     NaN       6

# %% [markdown]
# ### Reading Data from different sources

# %%
import pandas as pd 
from io import StringIO
Data = '{"employee_name":"James","email":"jvganeshh1@gmail.com","job_profile":[{"title1":"Team Lead","title2":"Sr.Developer"}]}'
df=pd.read_json(StringIO(Data))

# %%
df
# Out:
#   employee_name                 email  \
# 0         James  jvganeshh1@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Sr.Developer'}

# %%
df.to_json()
# Out:
# '{"employee_name":{"0":"James"},"email":{"0":"jvganeshh1@gmail.com"},"job_profile":{"0":{"title1":"Team Lead","title2":"Sr.Developer"}}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"employee_name":"James","email":"jvganeshh1@gmail.com","job_profile":{"title1":"Team Lead","title2":"Sr.Developer"}}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"employee_name":"James","email":"jvganeshh1@gmail.com","job_profile":{"title1":"Team Lead","title2":"Sr.Developer"}}]'

# %%
url = "https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes"
pd.read_html(url,match="Official",header=0)[0]
# Out:
#      ISO 3166[1] name[5]                       Official state name[6][a]  \
# 0    ISO 3166[1] name[5]                       Official state name[6][a]
# 1            Afghanistan          the Islamic Republic of Afghanistan[b]
# 2          Åland Islands                                     Åland[c][d]
# 3                Albania                         the Republic of Albania
# 4                Algeria     the People's Democratic Republic of Algeria
# ..                   ...                                             ...
# 267    Wallis and Futuna  the Territory of the Wallis and Futuna Islands
# 268  Western Sahara [an]      the Sahrawi Arab Democratic Republic[c][d]
# 269                Yemen                           the Republic of Yemen
# 270               Zambia                          the Republic of Zambia
# 271             Zimbabwe                        the Republic of Zimbabwe
#
#      Sovereignty [6][7][8] ISO 3166-1[2] ISO 3166-1[2].1 ISO 3166-1[2].2  \
# ...

# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/3.8 MB 7.2 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.8 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 6.9 MB/s eta 0:00:00
# ...
